# %% [markdown]
# **Capstone project**
#
# I am using this Jupyter Notebook for the capstone project

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **Hello Capstone Project Course!**
